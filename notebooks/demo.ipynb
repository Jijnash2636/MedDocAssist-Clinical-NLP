# %% [markdown]
# # Clinical Note AI System Demo
# IEEE Research Project - NLP-based Clinical Note Summarization and Coding Assistant

# %% [markdown]
# ## 8 Novelties Implemented
#
# 1. **Multimodal Clinical Understanding** - Audio (Whisper) + Image (Tesseract) + Text
# 2. **Clinical Text Normalization Layer** - Clean noisy medical text
# 3. **Privacy-aware AI Pipeline** - HIPAA compliant PHI de-identification
# 4. **Domain-Specific NER** - BioBERT for medical entities
# 5. **Clinical Abstractive Summarization** - Flan-T5 for summaries
# 6. **Semantic ICD Mapping + Explainability** - PubMedBERT embeddings
# 7. **Human-in-the-loop AI** - Confidence gate
# 8. **Clinical Decision Support System** - Drug interaction alerts

# %%
import sys
sys.path.insert(0, '.')

# %%
from src.main import ClinicalNoteAI
import json

# %%
system = ClinicalNoteAI()

# %%
test_note = """
Patient John Smith presents with chest pain and shortness of breath.
BP is 140/90. History of hypertension and diabetes.
Prescribed aspirin 81mg daily and metoprolol 25mg BID.
ECG shows normal sinus rhythm. CBC and CMP ordered.
"""

# %%
result = system.process_text(test_note)
print(json.dumps(result, indent=2))
